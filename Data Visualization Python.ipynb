# %%
import pandas as pd

data = pd.read_csv("data bank.csv", delimiter = ",") 

display(data.head(10))
# Out:
#    age         job   marital  education default  balance housing loan  \
# 0   59      admin.   married  secondary      no     2343     yes   no
# 1   56      admin.   married  secondary      no       45      no   no
# 2   41  technician   married  secondary      no     1270     yes   no
# 3   55    services   married  secondary      no     2476     yes   no
# 4   54      admin.   married   tertiary      no      184      no   no
# 5   42  management    single   tertiary      no        0     yes  yes
# 6   56  management   married   tertiary      no      830     yes  yes
# 7   60     retired  divorced  secondary      no      545     yes   no
# 8   37  technician   married  secondary      no        1     yes   no
# 9   28    services    single  secondary      no     5090     yes   no
#
#    contact  day month  duration  campaign  pdays  previous poutcome deposit
# 0  unknown    5   may      1042         1     -1         0  unknown     yes
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt

data = pd.read_csv("data bank.csv")

plt.scatter(data['age'], data['day'])

plt.title("Scatter Plot")

plt.xlabel('Age')
plt.ylabel('Day')

plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

data = pd.read_csv("data bank.csv")

plt.scatter(data['age'], data['day'])

plt.title("Scatter Plot")

plt.xlabel('Age')
plt.ylabel('Day')

plt.colorbar()
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

data = pd.read_csv("data bank.csv")

plt.plot(data['age'])
plt.plot(data['day'])

plt.title("Scatter Plot")

plt.xlabel('Age')
plt.ylabel('Day')

plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

data = pd.read_csv("data bank.csv")

plt.bar(data['age'], data['day'])

plt.title("Bar Chart")

plt.xlabel('Age')
plt.ylabel('Day')

plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

data = pd.read_csv("data bank.csv")

plt.hist(data['age'])

plt.title("Histogram")


plt.show()

# %%
import matplotlib.pyplot as plt
import pandas as pd

data = pd.read_csv('data bank.csv')

job = ['Services', 'Management', 'Admin','Retired']

day = [5,6,7,8]

plt.pie(day, labels=job)

plt.title("data bank")

plt.show()

# %%
import matplotlib.pyplot as plt
import pandas as pd

data = pd.read_csv('data bank.csv')

job = ['Services', 'Management', 'Admin','Retired']

day = [5,6,7,8]

plt.pie(day, labels=job)

plt.title("data bank")

plt.savefig("pie.jpg")

# %%
import pandas as pd
import matplotlib.pyplot as plt

data = pd.read_csv("data bank.csv")

plt.scatter(data['age'], data['day'])

plt.title("Scatter Plot")

plt.xlabel('Age')
plt.ylabel('Day')

plt.savefig("Scatter.jpg")

# %%
import pandas as pd
import matplotlib.pyplot as plt

data = pd.read_csv("data bank.csv")

plt.plot(data['age'])
plt.plot(data['day'])

plt.title("Scatter Plot")

plt.xlabel('Age')
plt.ylabel('Day')

plt.savefig("Plot.jpg")

# %%
import pandas as pd
import matplotlib.pyplot as plt

data = pd.read_csv("data bank.csv")

plt.bar(data['age'], data['day'])

plt.title("Bar Chart")

plt.xlabel('Age')
plt.ylabel('Day')

plt.savefig("Bar.jpg")

# %%
import pandas as pd
import matplotlib.pyplot as plt

data = pd.read_csv("data bank.csv")

plt.hist(data['age'])

plt.title("Histogram")


plt.savefig("hist.jpg")

# %%
import pandas as pd
import matplotlib.pyplot as plt

data = pd.read_csv("data bank.csv")

plt.scatter(data['age'], data['day'])

plt.title("Scatter Plot")

plt.xlabel('Age')
plt.ylabel('Day')

plt.colorbar()
plt.savefig("Scatter cr.jpg")
